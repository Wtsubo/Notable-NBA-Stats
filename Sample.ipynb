# %%
import os.path
from lib import stats_1min
player   = stats_1min.players.find_players_by_full_name('Yuta Watanabe')
player1min_obj = stats_1min.Nba_Player(player[0]["id"])
player1min_obj.data_path = os.getcwd() + "/data/{}".format(player1min_obj.player_slug)
player1min_obj.add_career_team()
player1min_obj.add_current_team("2022-23")
player1min_obj.check_team_game_info()
player1min_obj.get_heatmap("2022-23", "MIN", "Blues")
player1min_obj.get_heatmap("2022-23", "PTS", "BuGn")
player1min_obj.get_heatmap("2021-22", "MIN", "Blues")
player1min_obj.get_heatmap("2021-22", "PTS", "BuGn")
player1min_obj.get_heatmap("2020-21", "MIN", "Blues")
player1min_obj.get_heatmap("2020-21", "PTS", "BuGn")
player1min_obj.get_heatmap("2019-20", "MIN", "Blues")
player1min_obj.get_heatmap("2019-20", "PTS", "BuGn")
player1min_obj.get_heatmap("2018-19", "MIN", "Blues")
player1min_obj.get_heatmap("2018-19", "PTS", "BuGn")
# Out:
# <AxesSubplot:title={'center':'yuta-watanabe 2022-23 "PTS"'}, xlabel='Timestamp_Minutes', ylabel='Game_Label'>

# %%
import os.path
from lib import stats_1min
player   = stats_1min.players.find_players_by_full_name('Rui Hachimura')
player1min_obj = stats_1min.Nba_Player(player[0]["id"])
player1min_obj.data_path = os.getcwd() + "/data/{}".format(player1min_obj.player_slug)
player1min_obj.add_career_team()
player1min_obj.add_current_team("2022-23")
player1min_obj.check_team_game_info()
player1min_obj.get_heatmap("2022-23", "MIN", "Blues")
player1min_obj.get_heatmap("2022-23", "PTS", "BuGn")
player1min_obj.get_heatmap("2021-22", "MIN", "Blues")
player1min_obj.get_heatmap("2021-22", "PTS", "BuGn")
player1min_obj.get_heatmap("2020-21", "MIN", "Blues")
player1min_obj.get_heatmap("2020-21", "PTS", "BuGn")
player1min_obj.get_heatmap("2019-20", "MIN", "Blues")
player1min_obj.get_heatmap("2019-20", "PTS", "BuGn")
# Out:
# <AxesSubplot:title={'center':'rui-hachimura 2022-23 "PTS"'}, xlabel='Timestamp_Minutes', ylabel='Game_Label'>

# %%
# Work Around Data change.
#abce = stats_1min.pd.read_pickle("/Users/wtsubota/MyApp/check-nba/data/yuta-watanabe/yuta-watanabe_2018-19_Games_all.pkl")
#error = []
#for idx,row in abce.iterrows():
#    if type(row.MIN) is str :
#       error.append(row.GAME_ID)
#set(error)
#res = abce[abce["GAME_ID"] == "0021900118"]
##print("{:<8}{:<14}{:<14}".format(res.iloc[1]["GAME_ID"], res.iloc[1]["NICKNAME"], res.iloc[1]["MIN"]))
##print("{:<8}{:<14}{:<14}".format(res.loc[6,"GAME_ID"], res.loc[6,"NICKNAME"], res.loc[6,"MIN"]))
#res
